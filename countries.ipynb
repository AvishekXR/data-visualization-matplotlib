# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('polluted.csv')
df
# Out:
#      Unnamed: 0  Position      Country     City/Town  Year  PM2.5  \
# 0             0         1        India        Kanpur  2016    173
# 1             1         2        India     Faridabad  2016    172
# 2             2         3        India          Gaya  2016    149
# 3             3         4        India      Varanasi  2016    146
# 4             4         5        India         Patna  2016    144
# ..          ...       ...          ...           ...   ...    ...
# 495         495       496       Poland        Lublin  2016     27
# 496         496       497       Poland       Siedlce  2016     27
# 497         497       498       Poland     Trzebinia  2016     27
# 498         498       499  El Salvador  San Salvador  2016     27
# 499         499       500       Turkey         Sivas  2016     27
#
#     Temporal coverage  PM10 Temporal coverage.1  Database version (year)
# 0                >75%   319                 NaN                     2018
# ...

# %% [raw]
# Problem-1: Draw a line plot of which, the x-axis is the "Year" and the y-axis
# is sum of "PM2.5" of two countries Iran and China.

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Position', 'Country', 'City/Town', 'Year', 'PM2.5',
#        'Temporal coverage', 'PM10', 'Temporal coverage.1',
#        'Database version (year)'],
#       dtype='object')

# %%
x=df[df['Country'].isin(['Iran','China'])]
data=x.groupby('Year')['PM2.5'].sum()
year=data.index.tolist()
PM2=data.values
plt.plot(year,PM2,marker='o', markerfacecolor='yellow',label='PM2.5')
plt.xticks(year)
plt.xlabel('Year')
plt.ylabel('PM2.5')
plt.legend()
plt.title('Relation between year and sum of PM2.5 of China and Iran')
plt.show()

# %% [raw]
# Problem-2: Draw a histogram of the column "PM10" of which the y-axis
# represents the probability (see the documentation how to draw the probability).

# %%
plt.hist(df['PM10'],bins=12,density=True,alpha=0.7,color='pink', edgecolor='black',label='PM10')
plt.xlabel('PM10')
plt.ylabel('Probability')
plt.legend()
plt.show()

# %% [raw]
# Problem-3: Draw a scatter plot where x-axis represents "PM2.5" and y-axis
# represents "PM10" for two countries Poland and Chile.

# %%
x=df[df['Country'].isin(['Poland','Chile'])]
plt.scatter(x['PM2.5'],x['PM10'],marker='+',color='orange')
plt.xlabel('PM2.5')
plt.ylabel('PM10')
plt.title('Relation between PM10 and PM2.5 of Poland and Chile')

plt.show()

# %% [raw]
# Draw a pie chart of top 5 most frequent countries

# %%
country=df['Country'].value_counts().nlargest(5).index
freq=df['Country'].value_counts().nlargest(5).values
country
# Out:
# Index(['China', 'Iran', 'India', 'Chile', 'Poland'], dtype='object', name='Country')

# %%
explode=[0,0.2,0,0,0]
plt.pie(freq,labels=country,autopct='%0.1f%%',explode=explode,shadow=True)
plt.title('Top 5 most frequent countries')
plt.show()

# %% [raw]
#  Draw a bar chart which represents the counts of top 5 most
# frequent countries.

# %%
country=df['Country'].value_counts().nlargest(5).index
freq=df['Country'].value_counts().nlargest(5).values
plt.bar(country,freq,color=['red','yellow','green','orange','pink'])
plt.xlabel('Countries')
plt.ylabel('Frequenc'
plt.show()
